# %%
#!/usr/bin/env python3

########################################################################
# File: Chan_Nicholas_randomizedMotifSearch.ipynb
# Purpose: to find the promoter motif
#   main(infile='FILE_PATH',outfile='FILE_PATH', inCL=['-i 1000', '-p 1', '-k 13'])
#
# Author: Nicholas Chan
# History: 10/10/2021 Created
########################################################################

# %% [markdown]
# # Command Line Class
# Provided by Dr. B for parsing command line arguments

# %%
########################################################################
# CommandLine
########################################################################


class CommandLine():
    """
    Handle the command line, usage and help requests.

    CommandLine uses argparse,
    it implements a standard command line argument parser with various argument options,
    a standard usage and help, and an error termination exception Usage.
    """

    def __init__(self, inOpts = None):
        """
        CommandLine constructor.
        
        Implement a parser to interpret the command line argv string using argparse.
        """
        import argparse
        self.parser = argparse.ArgumentParser(
            description='Program prolog - a brief description of what this thing does',
            epilog='Program epilog - some other stuff you feel compelled to say',
            add_help=True,  # default is True
            prefix_chars='-',
            usage='%(prog)s [options] -option1[default] <input >output'
            )

        self.parser.add_argument('-m', '--minMotif', type=int, default=3, action='store', help='minimum motif length to consider for Markov Model')
        self.parser.add_argument('-M', '--maxMotif', type=int, default=8, action='store', help='maximum motif length to consider for Markov Model')
        self.parser.add_argument('-c', '--cutoff', type=int, default=-4, action='store', help='Significant Z-score cutoff value')
        # Command line option to use Gibbs sampling to find the optimal consensus motif.
#         self.parser.add_argument('-g', '--gibbsampling', type=float, default=1, action='store', help='implement Gibbs sampling')

        if inOpts is None:
            self.args = self.parser.parse_args()
        else:
            self.args = self.parser.parse_args(inOpts)

# %% [markdown]
# # FastAreader Class
# Provided by Dr. B for reading Fasta Files.

# %%
import sys

class FastAreader():
    """
    Read in files and preprocess.
    """
    def __init__(self, fname=''):
        """ Contructor: saves attribute fname. """
        self.fname = fname

    def doOpen(self):
        """ Open a file."""
        if self.fname == '':
            return sys.stdin
        else:
            return open(self.fname)

    def readFasta(self):
        """ Read in a fasta file and yield header and sequences separately"""
        header = ''
        sequence = ''

        with self.doOpen() as fileH:

            header = ''
            sequence = ''

            # skip to first fasta header
            line = fileH.readline()
            while not line.startswith('>'):
                line = fileH.readline()
            header = line[1:].rstrip()

            # Separate headers and sequences
            for line in fileH:
                if line.startswith('>'):
                    yield header, sequence
                    header = line[1:].rstrip()
                    sequence = ''
                else:
                    sequence += ''.join(line.rstrip().split()).upper()

        yield header, sequence

# %% [markdown]
# # Assignment 2 Notes
#
# ### NULL Model
# - For a Markov(1) Model, we consider a preceding base
#     - Ex:
#
#         $P(A|T_{prev}) = \frac{P(TA)}{P(T)} = \frac{\frac{c(TA)}{N}}{\frac{c(T)}{N}} = \frac{c(TA)}{c(T)}$
#
#         - N is not the same in the cases of TA and T, but the difference is negligible for now
# - Increasing the order of a Markov Model makes our model more informed
# - Check Week 2 Overview Video 3 for more details on detailed Markov Model for 4-mer described by $k_{1}k_{2}k_{3}k_{4}$

# %%
import sys
import os 
import numpy as np
from fastaReader import FastAreader

class SearchForMissing:
    def __init__(self, seqList, minMotif, maxMotif, zCut):
        self.seqList = seqList
        self.minMotif = minMotif
        self.maxMotif = maxMotif
        self.zCut = zCut
        
        self.N = self.genomeLen() # - self.maxMotif
        self.ctDict = self.ctDictMake()
        self.prDict = self.prDictMake()
        self.output = self.outputMake()

    def genomeLen(self):
        '''
        Takes the sum of sequence lengths from the list of sequences, seqList.
        seqList is made with the FastAreader class and has 1 fasta seq per entry.
        '''
        totLen = 0
        for seq in self.seqList:
            totLen += len(seq)
        return totLen

    def ctDictMake(self):
        '''
        Stores a dict of dicts
        {1:{'A':25, 'C':33,...}, ... ,8:{'AAAAGGGG':12, 'AAAATTTT':11, ...}}
        Reads over each sequence in the fasta. For each sequence, a sliding window
        moves over its respective sequence length and k-mers are counted.
        '''
        
        massDict = dict() # dictionary that holds dictionaries which hold k-mers and their respective counts
        for k in range(1, self.maxMotif+1): # Initialize dictionaries for min to max motif sizes within massDict; MAYBE START WITH 1 AND NOT MIN MOTIF
            massDict[k] = dict()
#         print(massDict)
        for seq in self.seqList:
            for k in range(1, self.maxMotif+1):
                for kmer_idx in range((len(seq)-k)):
                    kmer = seq[kmer_idx:kmer_idx+k]
                    if 'N' not in kmer:
                        if kmer in massDict[k]:
                            massDict[k][kmer] += 1
                        else:
                            massDict[k][kmer] = 1
        return massDict
                                
    def prDictMake(self): # VERY DEPENDENT ON ctDict
        massDict = dict() # dictionary that holds dictionaries which hold k-mers and their respective counts
        for k in range(self.minMotif, self.maxMotif+1): # Initialize dictionaries for min to max motif sizes within massDict
            massDict[k] = dict()
#         print(massDict)
        for k in range(self.minMotif, self.maxMotif+1):
            for kmer in self.ctDict[k].keys():
                if (kmer[:-1] not in self.ctDict[k-1]) or (kmer[1:] not in self.ctDict[k-1]) or (kmer[1:-1] not in self.ctDict[k-2]): # If sub seq is not in sequence count 
                    massDict[k][kmer] = 0
                else:
                    massDict[k][kmer] = (1/self.N) * ((self.ctDict[k-1][kmer[:-1]] * self.ctDict[k-1][kmer[1:]]) / self.ctDict[k-2][kmer[1:-1]])
        return massDict

    def outputMake(self):
        finalList = []
        for k in range(self.minMotif, self.maxMotif+1):
            banned = set()
            for kmer in self.ctDict[k].keys():
                if kmer not in banned: # interesting condition, is it implied that the reverse complement of the kmer is excluded?
                    # sequenceReverse entry
                    reverseCompKmer = revComp(kmer) # K-mer reverse compliment variable
                    tmpList = sorted([kmer,reverseCompKmer]) # Temporary list used for sorting kmer and reverse kmer for output
                    sequenceReverse = f"{tmpList[0]}:{tmpList[1]}" # sequence: reverse entry for output
                    # count entry
                    if kmer != reverseCompKmer: # Case 1: k-mer is not a palindrome
                        if reverseCompKmer in self.ctDict[k]:
                            count = self.ctDict[k][kmer] + self.ctDict[k][reverseCompKmer] 
                        else:
                            count = self.ctDict[k][kmer]
                    else: # Case 2: k-mer is a palindrome
                        count = count = self.ctDict[k][kmer]
                    # expectation entry
                    if reverseCompKmer in self.ctDict[k]:
                        Pr = self.prDict[k][kmer] + self.prDict[k][reverseCompKmer] 
#                         if kmer == "GCGATCGC":
#                             print(f'pr of GCGATCGC: {Pr}')
                    else: 
                        Pr = self.prDict[k][kmer]
                    expectation = Pr * (self.N) # look at this
                    # zscore entry
                    numerator = count - expectation
                    sd = (expectation * (1 - Pr))**0.5
                    zscore = numerator/sd
                    entry = (sequenceReverse, count, expectation, zscore, k)
                    banned.add(kmer) # Mark
                    banned.add(revComp(kmer))
                    finalList.append(entry)
        finalList.sort(key=lambda x:x[-2]) # sort by z-score
        finalList.sort(reverse=True, key=lambda x:x[-1]) # sort by motif length
        return finalList

# %%
### REVERESE COMPLIMENT FUNCTION ###
def revComp(seqStr):
    newStr = ''
    baseDict = {'A':'T', 'T':'A', 'C':'G', 'G':'C', 'N':'N'}
    for char in seqStr:
        newStr += baseDict[char]
    return newStr[::-1]

def main(infile, outfile='', inCL=None):
    '''
    This is the main function. Arguments are parsed here with the CommandLine class
    provided by Dr. B. Infile and outfile are also read here, with an outfile file being 
    optional. IF no outfile is provided, output is printed. Infile is read in through the
    readData function which returns fasta file information for the RandomMotifSearch to read.
    This way, input only needs to be read once. RandomMotifSearch is called i number of times,
    with the relative entropy score and consensus sequence being stored in the motifAndScore list.
    The highest RE Score and its corresponding consensus sequence are written to outup.
    '''

    myCommandLine = CommandLine(inCL)
    minMotif = myCommandLine.args.minMotif
    maxMotif = myCommandLine.args.maxMotif
    cutoff = myCommandLine.args.cutoff
    
    def readData(infile:'str') -> 'tuple(list,str)':
        '''
        Reads in fasta file as input. 
        Returns [0]: a list of seqs [1]: a string of catted seqs.
        '''
        seqList = []
        readData = FastAreader(infile).readFasta()
        for line in readData:
            seqList.append(line[1]) # Append seq and not head to seqList
        return seqList
    
    seqList = readData(infile) # Saves output of FastAreader(infile).readFasta() as seqList
    
    sfm = SearchForMissing(seqList, minMotif, maxMotif, cutoff)
    print()
    for line in sfm.output:
        if line[3] >= :
            break
        print('{0:17}\t{1:0d}\t{2:0.2f}\t{3:0.2f}'.format(line[0], line[1],line[2],line[3]))

# %%
if __name__ == "__main__":
    '''
    This is where the main function is executed.
    Usage:
        main(infile='FILE_PATH', outfile='FILE_PATH', inCL=[-ipk] )
    Arguments:
        --minMotif
            Minimum motif length to consider for Markov Model
        --maxMotif
            Maximum motif length to consider for Markov Model
        --cutoff
            Significant Z-score cutoff value
    '''
    main(infile='mdata/Arthrospira-platensis-NIES-39.fna', inCL=['-m 3', '-M 8', '-c -4'])
#     main(infile='mdata/Arthrospira-platensis-NIES-39.fna', inCL=['--minMotif 3', '--maxMotif 8', '--cutoff -4'])
# Out:
# GCGATCGC:GCGATCGC	7683	15876.38	-65.10
# AATTAATT:AATTAATT	558	1290.10	-20.38
# AAAATTTT:AAAATTTT	501	1092.52	-17.90
# TTAATTAA:TTAATTAA	537	1102.21	-17.03
# AAATATTT:AAATATTT	365	852.58	-16.70
# ATAATTAT:ATAATTAT	364	840.33	-16.43
# CAAATTTG:CAAATTTG	245	579.12	-13.88
# ACAATTGT:ACAATTGT	115	375.36	-13.44
# CTATCGGC:GCCGATAG	119	176.59	-4.33
# GGTTGGAA:TTCCAACC	188	257.53	-4.33
# ACAGACAT:ATGTCTGT	129	188.41	-4.33
# ATGAAGCG:CGCTTCAT	174	241.20	-4.33
# AAATTAGA:TCTAATTT	530	639.41	-4.33
# ACTCGAGT:ACTCGAGT	16	45.02	-4.32
# ATAGCGAA:TTCGCTAT	206	278.08	-4.32
# GTGATATA:TATATCAC	151	214.23	-4.32
# ACTTCAAT:ATTGAAGT	287	370.08	-4.32
# CTAAGTAG:CTACTTAG	67	112.84	-4.32
# AGGATATA:TATATCCT	296	380.10	-4.31
# ACGCTACT:AGTAGCGT	71	117.82	-4.31
# ATGTCGCA:TGCGACAT	57	100.16	-4.31
# ATTCCAGG:CCTGGAAT	223	297.31	-4.31
# GCCTTGCC:GGCAAGGC	68	114.01	-4.31
# AAGGAGCC:GGCTCCTT	114	170.16	-4.31
# CTCAAGAC:GTCTTGAG	142	203.39	-4.30
# CGGGTGAA:TTCACCCG	161	225.67	-4.30
# ACGCTAGT:ACTAGCGT	44	83.26	-4.30
# CCCGGAAC:GTTCCGGG	265	344.91	-4.30
# AAAGCTGA:TCAGCTTT	420	517.91	-4.30
# ACATTCGT:ACGAATGT	40	77.99	-4.30
# GTGACTTA:TAAGTCAC	101	154.45	-4.30
# ATAATCAT:ATGATTAT	604	719.33	-4.30
# ACTCAAGT:ACTTGAGT	191	260.33	-4.30
# AAATGTAC:GTACATTT	107	161.62	-4.30
# ACGTTATC:GATAACGT	74	121.30	-4.29
# CCAATTAA:TTAATTGG	553	663.63	-4.29
# AAGCTATA:TATAGCTT	223	297.00	-4.29
# AGCGATCA:TGATCGCT	128	186.63	-4.29
# CAGGGAAA:TTTCCCTG	409	505.44	-4.29
# ACAGAGTC:GACTCTGT	87	137.23	-4.29
# AGGAGCCA:TGGCTCCT	186	254.36	-4.29
# AACATATA:TATATGTT	215	287.69	-4.29
# CATACACC:GGTGTATG	68	113.68	-4.28
# ACTATTTC:GAAATAGT	318	404.12	-4.28
# AACACAGA:TCTGTGTT	179	246.18	-4.28
# AACCTCAT:ATGAGGTT	191	260.04	-4.28
# CGAATGCC:GGCATTCG	71	117.38	-4.28
# CGTCTACC:GGTAGACG	70	116.09	-4.28
# CGGAAGGA:TCCTTCCG	103	156.51	-4.28
# AAAGGTCA:TGACCTTT	192	261.10	-4.28
# AAGGGATA:TATCCCTT	197	266.80	-4.27
# CGCCAACC:GGTTGGCG	319	404.96	-4.27
# GTCAATTA:TAATTGAC	476	578.61	-4.27
# GGAGTGCC:GGCACTCC	69	114.67	-4.27
# GGACGGTA:TACCGTCC	99	151.41	-4.26
# ATTTAGCA:TGCTAAAT	343	431.44	-4.26
# AATTCATA:TATGAATT	222	295.10	-4.26
# CGTACATC:GATGTACG	23	54.36	-4.25
# AGACAAAT:ATTTGTCT	252	329.17	-4.25
# TCAATGCA:TGCATTGA	88	137.95	-4.25
# ATCGAAAG:CTTTCGAT	112	166.94	-4.25
# GCGAATTA:TAATTCGC	192	260.64	-4.25
# GCTATGCC:GGCATAGC	91	141.56	-4.25
# TACGATGA:TCATCGTA	94	145.20	-4.25
# CGCTGCGA:TCGCAGCG	113	168.08	-4.25
# ATACACAG:CTGTGTAT	82	130.53	-4.25
# CTCCGTTC:GAACGGAG	57	99.31	-4.25
# ACATTTAT:ATAAATGT	212	283.38	-4.24
# AGTAGCGG:CCGCTACT	112	166.75	-4.24
# CATCCTGG:CCAGGATG	151	212.85	-4.24
# AAAAGGTC:GACCTTTT	135	194.05	-4.24
# CCGATAGC:GCTATCGG	195	263.85	-4.24
# GATACCCA:TGGGTATC	256	333.36	-4.24
# CCGGGTTC:GAACCCGG	259	336.75	-4.24
# GAGAGTAC:GTACTCTC	53	94.10	-4.24
# ATGCCAGG:CCTGGCAT	97	148.65	-4.24
# AGGTCAGG:CCTGACCT	147	208.11	-4.24
# CAGATTCC:GGAATCTG	142	202.21	-4.23
# ACCCTATG:CATAGGGT	108	161.86	-4.23
# GCTATCGA:TCGATAGC	128	185.65	-4.23
# ATAATGCA:TGCATTAT	107	160.60	-4.23
# GTCAGGCA:TGCCTGAC	57	99.10	-4.23
# CCTAGACA:TGTCTAGG	105	158.18	-4.23
# GTAAGCAA:TTGCTTAC	99	150.94	-4.23
# AGCATGAA:TTCATGCT	141	200.92	-4.23
# ATGTATTC:GAATACAT	93	143.66	-4.23
# GCTTAACA:TGTTAAGC	108	161.75	-4.23
# GATTTCTA:TAGAAATC	323	408.38	-4.23
# ACCCGGGT:ACCCGGGT	47	86.19	-4.22
# GACCACTC:GAGTGGTC	59	101.53	-4.22
# AAAGGAAG:CTTCCTTT	148	208.99	-4.22
# AACCGTGG:CCACGGTT	130	187.81	-4.22
# CTGACCAG:CTGGTCAG	218	289.71	-4.21
# CGTATCAG:CTGATACG	69	113.97	-4.21
# ACATTGTC:GACAATGT	100	151.91	-4.21
# AAATCGGT:ACCGATTT	331	416.93	-4.21
# AACGCAGA:TCTGCGTT	58	100.11	-4.21
# GCTTATTA:TAATAAGC	212	282.76	-4.21
# CAAGCTTG:CAAGCTTG	11	36.38	-4.21
# CATTGCAA:TTGCAATG	67	111.41	-4.21
# AGCAGTGG:CCACTGCT	244	319.10	-4.20
# CACCCAAA:TTTGGGTG	493	595.57	-4.20
# AGCCGTTA:TAACGGCT	232	305.45	-4.20
# ATACGATG:CATCGTAT	56	97.49	-4.20
# CCAACTAA:TTAGTTGG	203	272.29	-4.20
# ACCTTGAT:ATCAAGGT	256	332.56	-4.20
# CCCTGAAC:GTTCAGGG	156	217.97	-4.20
# CATGCGTC:GACGCATG	24	55.13	-4.19
# CCTTTTAA:TTAAAAGG	209	278.97	-4.19
# AAGGTTAT:ATAACCTT	205	274.38	-4.19
# AAGGGGCG:CGCCCCTT	164	227.04	-4.18
# CTTTGGTC:GACCAAAG	218	289.12	-4.18
# GATTAGAC:GTCTAATC	127	183.67	-4.18
# GCGAGACC:GGTCTCGC	81	128.37	-4.18
# ACCCCGCT:AGCGGGGT	115	169.42	-4.18
# ACGGAACA:TGTTCCGT	112	165.83	-4.18
# AACTCTCA:TGAGAGTT	350	437.41	-4.18
# CTTACACC:GGTGTAAG	89	138.03	-4.17
# GAAGTGTA:TACACTTC	73	118.36	-4.17
# TCCCGGGA:TCCCGGGA	27	59.03	-4.17
# TAGCTAGA:TCTAGCTA	119	173.97	-4.17
# ACCGTATG:CATACGGT	54	94.47	-4.16
# CAGCAATC:GATTGCTG	215	285.33	-4.16
# GACATGGC:GCCATGTC	98	148.76	-4.16
# AACAGTGA:TCACTGTT	156	217.35	-4.16
# ACTTTCAA:TTGAAAGT	266	343.07	-4.16
# TCCATGAA:TTCATGGA	158	219.67	-4.16
# ACCGGAGT:ACTCCGGT	183	248.60	-4.16
# ATAAGATG:CATCTTAT	87	135.39	-4.16
# GTTATTTA:TAAATAAC	394	485.58	-4.16
# CAGTCACC:GGTGACTG	151	211.41	-4.15
# GAGTCGGC:GCCGACTC	105	157.06	-4.15
# ACGCTGTC:GACAGCGT	46	84.07	-4.15
# AAAATCCT:AGGATTTT	611	722.57	-4.15
# ATGGGAAG:CTTCCCAT	266	342.80	-4.15
# CTTGTTCC:GGAACAAG	159	220.60	-4.15
# CTCAGCCC:GGGCTGAG	133	190.18	-4.15
# CGGACTTA:TAAGTCCG	113	166.50	-4.15
# CTCAACAC:GTGTTGAG	108	160.52	-4.15
# AAAAGTAT:ATACTTTT	303	384.16	-4.14
# GCCTCTTA:TAAGAGGC	53	92.92	-4.14
# AAGTGTAT:ATACACTT	83	130.25	-4.14
# CACCCTAG:CTAGGGTG	246	320.06	-4.14
# ACTTTGAG:CTCAAAGT	229	300.78	-4.14
# ACGTCTCA:TGAGACGT	37	72.16	-4.14
# GAGGATTA:TAATCCTC	323	406.41	-4.14
# ACTAGTGA:TCACTAGT	5	26.16	-4.14
# GCGGAAAC:GTTTCCGC	337	421.97	-4.14
# GATATTCC:GGAATATC	377	466.20	-4.13
# AATAATGT:ACATTATT	227	298.31	-4.13
# GCATTATA:TATAATGC	165	227.20	-4.13
# CCACAGAC:GTCTGTGG	228	299.39	-4.13
# AGGTTCCG:CGGAACCT	194	260.58	-4.12
# GGGTAAAC:GTTTACCC	321	403.84	-4.12
# AGAGACCA:TGGTCTCT	119	173.26	-4.12
# GTTTTTCA:TGAAAAAC	428	522.19	-4.12
# CTATACCC:GGGTATAG	155	215.51	-4.12
# ACGAAATA:TATTTCGT	105	156.55	-4.12
# GACCACTA:TAGTGGTC	131	187.35	-4.12
# ACGTTTCT:AGAAACGT	52	91.34	-4.12
# AATAGCCA:TGGCTATT	524	626.98	-4.11
# GCTTACAA:TTGTAAGC	136	193.16	-4.11
# ATGGTTGA:TCAACCAT	337	421.41	-4.11
# ATCCGAGA:TCTCGGAT	197	263.77	-4.11
# ACGCCACA:TGTGGCGT	58	98.87	-4.11
# GTTCCCTA:TAGGGAAC	255	329.62	-4.11
# CTTTCTTC:GAAGAAAG	175	238.45	-4.11
# AGGCATGG:CCATGCCT	97	146.75	-4.11
# AAGGCAAT:ATTGCCTT	344	428.95	-4.10
# GCGTTGCC:GGCAACGC	37	71.71	-4.10
# ACAAGTGT:ACACTTGT	46	83.42	-4.10
# CTGCTGCC:GGCAGCAG	134	190.53	-4.10
# AATCAGGA:TCCTGATT	504	604.71	-4.10
# AAAGCCTA:TAGGCTTT	334	417.69	-4.09
# GAGAGGAA:TTCCTCTC	162	223.16	-4.09
# CGCCGCAG:CTGCGGCG	89	136.88	-4.09
# AATGCGGA:TCCGCATT	202	269.12	-4.09
# CGGTGTCA:TGACACCG	95	144.07	-4.09
# ACCGGGTC:GACCCGGT	172	234.62	-4.09
# AGAACCCA:TGGGTTCT	322	404.17	-4.09
# CGCTCTTA:TAAGAGCG	34	67.60	-4.09
# AATGTCCT:AGGACATT	120	173.88	-4.09
# CCCTGCCA:TGGCAGGG	198	264.43	-4.09
# CGTTAACG:CGTTAACG	46	83.28	-4.09
# CTCATACC:GGTATGAG	98	147.62	-4.08
# GGTTTCCA:TGGAAACC	390	479.40	-4.08
# AAGTCGCA:TGCGACTT	93	141.59	-4.08
# GCTAAAGA:TCTTTAGC	238	309.87	-4.08
# CTCATGAG:CTCATGAG	32	64.89	-4.08
# AGTACTCA:TGAGTACT	3	22.24	-4.08
# GGTAGGTA:TACCTACC	159	219.38	-4.08
# CCTTGAAC:GTTCAAGG	143	200.74	-4.08
# TAACCAGA:TCTGGTTA	276	352.48	-4.07
# AGTCACCC:GGGTGACT	182	245.88	-4.07
# AAATTTGT:ACAAATTT	453	548.37	-4.07
# GCTTGTTA:TAACAAGC	129	184.29	-4.07
# AGGTTATG:CATAACCT	216	284.68	-4.07
# AAGTAATA:TATTACTT	157	216.94	-4.07
# ACGGTCAT:ATGACCGT	122	175.97	-4.07
# CCCCATCC:GGATGGGG	188	252.64	-4.07
# CGCCACCC:GGGTGGCG	347	431.46	-4.07
# GGTCTTCA:TGAAGACC	112	164.05	-4.06
# GATAAATA:TATTTATC	528	629.93	-4.06
# TCAGCGAA:TTCGCTGA	132	187.62	-4.06
# CGCGTATC:GATACGCG	16	42.45	-4.06
# TGTCATAA:TTATGACA	140	196.97	-4.06
# AGTAGGTA:TACCTACT	219	287.87	-4.06
# AGTCCTAT:ATAGGACT	106	156.82	-4.06
# ACGATGGG:CCCATCGT	72	115.64	-4.06
# CACTGCCC:GGGCAGTG	60	100.73	-4.06
# CCGCGCGG:CCGCGCGG	29	60.57	-4.06
# CGCACCAA:TTGGTGCG	292	369.97	-4.05
# GAAGGGTA:TACCCTTC	93	141.14	-4.05
# GCCCTTTA:TAAAGGGC	80	125.37	-4.05
# AAGTCGGG:CCCGACTT	154	213.15	-4.05
# CATGCCCA:TGGGCATG	69	111.84	-4.05
# ACCTGTTG:CAACAGGT	365	451.03	-4.05
# CACCATAA:TTATGGTG	306	385.52	-4.05
# AGGGACAT:ATGTCCCT	93	141.10	-4.05
# GCGTATGA:TCATACGC	18	45.23	-4.05
# ACTCCCAA:TTGGGAGT	409	499.48	-4.05
# GTCACCAA:TTGGTGAC	218	286.53	-4.05
# CCATTCCA:TGGAATGG	210	277.43	-4.05
# ACTGGGTC:GACCCAGT	100	149.50	-4.05
# GAAAACTA:TAGTTTTC	272	347.44	-4.05
# GACCCGTC:GACGGGTC	81	126.46	-4.04
# TCCCGGAA:TTCCGGGA	380	467.37	-4.04
# ACGGTTAT:ATAACCGT	161	221.09	-4.04
# TAGGCTCA:TGAGCCTA	105	155.38	-4.04
# CAAGCAAA:TTTGCTTG	184	247.52	-4.04
# CATTCCAG:CTGGAATG	189	253.23	-4.04
# CTGGTTCA:TGAACCAG	220	288.56	-4.04
# ACCCTAGG:CCTAGGGT	243	314.58	-4.04
# CCTGAAGC:GCTTCAGG	140	196.58	-4.04
# CGTTGCAC:GTGCAACG	54	92.87	-4.03
# ACATCAAT:ATTGATGT	410	500.20	-4.03
# ACACCTTC:GAAGGTGT	118	170.69	-4.03
# GCCAACCC:GGGTTGGC	259	332.53	-4.03
# ATTCGCTG:CAGCGAAT	119	171.84	-4.03
# AATCATCT:AGATGATT	512	611.64	-4.03
# ACAAGACT:AGTCTTGT	104	153.99	-4.03
# TAAGGCAA:TTGCCTTA	134	189.44	-4.03
# AGTATACT:AGTATACT	31	62.95	-4.03
# AGTTCGTA:TACGAACT	74	117.68	-4.03
# ATCAGACA:TGTCTGAT	198	263.32	-4.03
# TAGGACGA:TCGTCCTA	93	140.69	-4.02
# CTTTGATC:GATCAAAG	113	164.57	-4.02
# AAAGTACA:TGTACTTT	194	258.63	-4.02
# AAGTACGT:ACGTACTT	9	31.57	-4.02
# TGTATACA:TGTATACA	40	74.73	-4.02
# CAGTCAGG:CCTGACTG	151	209.08	-4.02
# CGTTCAGA:TCTGAACG	65	106.44	-4.02
# ACAGGTCT:AGACCTGT	152	210.16	-4.01
# GCGAGTTA:TAACTCGC	172	233.27	-4.01
# AAGGTTGG:CCAACCTT	260	333.17	-4.01
# TGCGAGAA:TTCTCGCA	200	265.29	-4.01
# GTTTATAA:TTATAAAC	240	310.63	-4.01
# CTAATTGA:TCAATTAG	418	508.26	-4.00
# CGACGCTA:TAGCGTCG	55	93.77	-4.00
# AGGCAGGA:TCCTGCCT	100	148.81	-4.00
# AACGGCGG:CCGCCGTT	285	361.02	-4.00
# GCGGTGGA:TCCACCGC	176	237.68	-4.00
# GATGGGTA:TACCCATC	155	213.45	-4.00
# ATAAAACG:CGTTTTAT	137	192.51	-4.00
# GGACAAAA:TTTTGTCC	365	449.84	-4.00
# AGCGAGAC:GTCTCGCT	88	134.37	-4.00

# %%
# INSPECTION

# INSPECTION TEAM
# Jodi Lee
# Maxim Firsov
# Hsiang-Yun Lu (Eloise)
# Gabriel Aguiar

# RESPONSES
# - Markdown comments
# - Get more docstrings
# - Make change so that infile is only read once
# - Finish main function

# CORRECTIONS
# - Made markdown comments
# - Made more docstrings and comments
# - Infile is only read once in the main function
# - Main function was put together
